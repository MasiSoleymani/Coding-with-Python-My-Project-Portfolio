# %% [markdown]
# #### Classes & Objects
#     * A class is an object constructor or a "blueprint" for creating objects.
#     * Objects are nothing but an encapsulation of multiple variables and functions in a single entity.
#     * Objects get their variables and functions from classes.
#     * self parameter is a reference to current/newly created object of class. It is used to access class variables/functions etc.
#     * self must be first parameter of any function in class.
#
#
#     My Comments:
#     My list is object of list data type. List is class data type for which we are declaring an object. And when you craete an object it is called an object oriented programming.Object is created from a certain calss. Whatever fucntion you have defined inside the class, this object is able to access it using dot operator.
#     in the following examole mylist are object of list class
#     mylist.append()
#     mylist.copy(), ....
#
#     Objects/ variables in object oriented programming languages are initializied for a certain class. And inside the class we as a developers defin multiple fucntions. Classes are collection of multiple fucntions and objects/variables. Using the objet/vaeriable and dot operator '.' you as user are able to access different functions as well as variables. Like in this example, mylist is varibal of list calss type, and using the dot I was able to easily access the function.

# %%
# declare a class with class name
class className:
    # declare a function with parameter "name"
    def createName(self, name):
        # intialize object with self.name = name passed by user
        self.name = name
    
    def greetings(self):
        # self.name is public access modifiers
        print("Hello ", self.name)

# obj is object of class
obj = className()

# %%
# calling a function using an object
obj.createName("Hasan")
obj.greetings()
# Out:
# Hello  Hasan

# %%
#My code based ont the above code"
class className:
    # declare a function with parameter "name"
    def createName(self, name, age, Dep):
        # intialize object with self.name = name passed by user
        self.name = name
        
    
    def greetings(self):
        # self.name is public access modifiers
        print("Hello and Welcome", self.name)

# obj is object of class
obj = className()

# %%
# calling a function using an object
obj.createName("Hasan", "35", "F")
obj.greetings()
# Out:
# Hello and Welcome Hasan

# %%
class Employee:
    #my first funciotn that I created is init function, which is taking these parameters which is
    #name, birthdate, address, contact, email
    def __init__(self, name, birthdate, address, contact, email):
 # now how we initialize it, we need to take help of self which mean help indicate my object names
#in the code below self.name and self.address , etc are objects and in that object itseld you have to mention  
#the name and that will be allocated to the object's name.
# So as user prits object.name it will print the name which you have to pass, like abc
        self.name = name
        self.birthdate = birthdate
        self.address = address
        self.contact = contact
        self.email = email

# %%
#we import  datetime as we need date format for our code, one of our value is related to date
#now here we need ti create an object
#self is reference to newly created object that will be declared by users.
#emp is  object of my employee in the previouis line code (class Employee:)
#now we need to add values of name, birthdate, address, contact, email
import datetime

#datetie provide me with a function called datet function. So we add it before date.
emp = Employee("Eleven Hopper", 
               datetime.date(1999,3,13),  # year, month, date
               "Street No. 12, GreenVille",
               "5555 456 0987",
               "eleven_hopper@example.com")

# %%
#dot is used to access the functions and variables names.
print(emp.name, emp.email)
# Out:
# Eleven Hopper eleven_hopper@example.com

# %%
# my modification and manupolation, my code
print(emp.name, emp.email, emp.birthdate, emp.address, emp.contact)
# Out:
# Eleven Hopper eleven_hopper@example.com 1999-03-13 Street No. 12, GreenVille 5555 456 0987

# %% [markdown]
# #### Public , Private and Protected Access Modifiers

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-3.png](attachment:image-3.png)
# ![image-2.png](attachment:image-2.png)

# %%
# Example of public access modifier in a class
#self.name = name and self.age = age  are public modifers
#similarly all functions like def.callsName() are public fuction.
#it is two underscores attached.
class Employee:
    # declare constructor
    def __init__(self, name, age):
        # public data members
        self.employeeName = name
        self.employeeAge = age
    
    # public member function
    def printAge(self):
        # accessing public data member within class
        print("Employee Age: ", self.employeeAge)

# %%
# create object of class Employee
empobj = Employee("Omerah", 25)
# calling a public member function of class
empobj.printAge()
# Out:
# Employee Age:  25

# %%
# Example of private access modifier in a class
# super class
class Employee:
    # protected data members
    #they have underscore before object's names and have None
    _name = None
    _department = None
    
    # declare constructor
    def __init__(self, name, department):
        # protected data members
        self._name = name
        self._department = department
    
    # protected member function
    def _display(self):
        # accessing public data member within class
        print("Employee Name: ", self._name)
        print("Employee Department: ", self._department)

# %%
# derived class
#pay attention to the size and number of underline
class EmpDetails(Employee):
    def __init__(self, name, department):
        Employee.__init__(self, name, department)
    
    # public data members
    def displayDetails(self):
        # accessing protected data members of super class
        print("Name: " , self._name)
        self._display()

# declare object of derived class
obj = EmpDetails("Snehal", "Data Science")
obj.displayDetails()
# Out:
# Name:  Snehal
# Employee Name:  Snehal
# Employee Department:  Data Science

# %%
# Private Access Modifier
#pay attention to the size and number of underline
class Employee:
    # protected data members
    __name = None
    __department = None
    
    # declare constructor
    def __init__(self, name, department):
        # protected data members
        self.__name = name
        self.__department = department
    
    # private member function
    def __display(self):
        
        # accessing private data member within class
        print("Employee Name: ", self.__name)
        print("Employee Department: ", self.__department)
    
    # public function
    def accessPrivateFunction(self):
        self.__display()

# %%
# create object
name = input("Enter Emp Name: ")
dept = input("Enter Emp Department: ")
obj = Employee(name, dept)
obj.accessPrivateFunction()
# Out:
# Enter Emp Name: Ali
# Enter Emp Department: Data
# Employee Name:  Ali
# Employee Department:  Data

# %% [markdown]
# #### Inheritance
#     * Inheritance provides code reusability in the program because we can use an existing class (Super Class/Parent Class/Base Class) to create a new class (Sub Class/Child Class/Derived Class) instead of creating it from scratch.

# %%
# Parent Class Declaration
class Parent:
    # constructor
    def __init__(self, name):
        self.name = name
        print("Calling name : " , self.name)
    def parentMethod(self):
        print("Calling parent method")

# Derived / child class declaration
class Child(Parent):
    def __init__(self):
        print("Calling child constructor")
    def childMethod(self):
        print("Calling child method")

# %%
# object of base class
obj1 = Parent("Python")
# object of child class
obj2 = Child()
# Out:
# Calling name :  Python
# Calling child constructor

# %%
obj2.parentMethod()
obj2.childMethod()
# Out:
# Calling parent method
# Calling child method

# %% [raw]
# # Multi-Level Inheritance
# class Parent:
#     statement(s)
#
# class Child(Parent):
#     statement(s)
#
# class GrandChild(Child):
#     statement(s)

# %% [raw]
# # Hierarical Inheritance
# class Parent:
#     statement(s)
#
# # Two derived class using one parent class
# class Child1(Parent):
#     statement(s)
#
# class Child2(Child):
#     statement(s)

# %% [raw]
# Polymorphism;
# Two different codes gives you same output
# you can use Length function to see length of string value or numerical value/ data type.
# Same function getting used for many purposes. Like length or print function.Print cand be used to print many things.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
## Polymorphic Functions
# var3 = 0 (default declaration)
def addition(var1, var2, var3 = 0):
    return var1 + var2 + var3

print(addition(20, 30))
# Out:
# 50

# %%
print(addition(20, 30, 40))
# Out:
# 90

# %%
print(addition(20, 30, 40))
# Out:
# 90
